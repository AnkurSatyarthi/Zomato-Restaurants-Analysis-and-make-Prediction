# %%
using DataFrames,CSV,TypedTables,Plots,GLM
zomato=DataFrame(CSV.File("raw_data/zomato.csv"))
# Out:
# 7105×12 DataFrame
#   Row │ Column1  Unnamed: 0  restaurant name                    restaurant typ ⋯
#       │ Int64    Int64       String                             String31       ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │       0           0  #FeelTheROLL                       Quick Bites    ⋯
#     2 │       1           1  #L-81 Cafe                         Quick Bites
#     3 │       2           2  #refuel                            Cafe
#     4 │       3           3  '@ Biryani Central                 Casual Dining
#     5 │       4           4  '@ The Bbq                         Casual Dining  ⋯
#     6 │       5           5  '@99                               Takeaway, Deli
#     7 │       6           6  '@Italy                            Casual Dining
#     8 │       7           7  '@North Parontha Hut               Takeaway, Deli
#   ⋮   │    ⋮         ⋮                       ⋮                          ⋮      ⋱
# ...

# %%
describe(zomato)
# Out:
# 12×7 DataFrame
#  Row │ variable               mean     min              median  max            ⋯
#      │ Symbol                 Union…   Any              Union…  Any            ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Column1                3552.0   0                3552.0  7104           ⋯
#    2 │ Unnamed: 0             3552.0   0                3552.0  7104
#    3 │ restaurant name                 #FeelTheROLL             re:cess - Hilt
#    4 │ restaurant type                 Bakery                   Takeaway, Deli
#    5 │ rate (out of 5)        3.51425  1.8              3.5     4.9            ⋯
#    6 │ num of ratings         188.921  1                40.0    16345
#    7 │ avg cost (two people)  540.286  40.0             400.0   6000.0
#    8 │ online_order                    No                       Yes
#    9 │ table booking                   No                       Yes            ⋯
# ...

# %%
zomato
# Out:
# 7105×12 DataFrame
#   Row │ Column1  Unnamed: 0  restaurant name                    restaurant typ ⋯
#       │ Int64    Int64       String                             String31       ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │       0           0  #FeelTheROLL                       Quick Bites    ⋯
#     2 │       1           1  #L-81 Cafe                         Quick Bites
#     3 │       2           2  #refuel                            Cafe
#     4 │       3           3  '@ Biryani Central                 Casual Dining
#     5 │       4           4  '@ The Bbq                         Casual Dining  ⋯
#     6 │       5           5  '@99                               Takeaway, Deli
#     7 │       6           6  '@Italy                            Casual Dining
#     8 │       7           7  '@North Parontha Hut               Takeaway, Deli
#   ⋮   │    ⋮         ⋮                       ⋮                          ⋮      ⋱
# ...
